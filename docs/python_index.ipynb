# %% [markdown]
# # [chemeng316_fluids](https://docNathanM.github.io/chemeng316_fluids)
#
# ## Index of Python Libraries used in this Repository
#
# ### CoolProp
# * [1.3.1.3 CoolProp PropsSI Example](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.1.3-CoolProp-PropsSI-Example)
# * [1.3.1.3 CoolProp PropsSI Example](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.1.3-CoolProp-PropsSI-Example)
# * [1.4 Queary Wolfram Alpha for Information](https://docNathanM.github.io/chemeng316_fluids/01.04-Queary-Wolfram-Alpha.html#1.4-Queary-Wolfram-Alpha-for-Information)
#
# ### math
# * [1.1.6.5 Temperature and Other Offset (Non-multiplicative) Units](https://docNathanM.github.io/chemeng316_fluids/01.01-Units-and-Engineering-Calculations.html#1.1.6.5-Temperature-and-Other-Offset-(Non-multiplicative)-Units)
# * [1.2.1.5 Temperature and Other Offset (Non-multiplicative) Units](https://docNathanM.github.io/chemeng316_fluids/01.02-Units-Template-with-pint.html#1.2.1.5-Temperature-and-Other-Offset-(Non-multiplicative)-Units)
#
# ### matplotlib
# * [0.2.3.4 Plotting](https://docNathanM.github.io/chemeng316_fluids/00.02-Getting-Started-with-Jupyter-Notebooks-and-Python.html#0.2.3.4-Plotting)
#
# ### numpy
# * [0.2.3.1 Arithmetic Operations](https://docNathanM.github.io/chemeng316_fluids/00.02-Getting-Started-with-Jupyter-Notebooks-and-Python.html#0.2.3.1-Arithmetic-Operations)
# * [0.2.3.4 Plotting](https://docNathanM.github.io/chemeng316_fluids/00.02-Getting-Started-with-Jupyter-Notebooks-and-Python.html#0.2.3.4-Plotting)
# * [1.3.3 Calculations](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.3-Calculations)
# * [1.4 Queary Wolfram Alpha for Information](https://docNathanM.github.io/chemeng316_fluids/01.04-Queary-Wolfram-Alpha.html#1.4-Queary-Wolfram-Alpha-for-Information)
#
# ### pint
# * [1.3.1.1 Always need Units!](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.1.1-Always-need-Units!)
# * [1.3.1.1 Always need Units!](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.1.1-Always-need-Units!)
# * [1.3.2 Example](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.2-Example)
# * [1.3.2 Example](https://docNathanM.github.io/chemeng316_fluids/01.03-Properties-of-Pure-Substances-with-CoolProp.html#1.3.2-Example)
#
# ### sympy
# * [0.2.4 Solving Equations using Sympy](https://docNathanM.github.io/chemeng316_fluids/00.02-Getting-Started-with-Jupyter-Notebooks-and-Python.html#0.2.4-Solving-Equations-using-Sympy)
# * [0.3.3 Solving linear equations using Sympy](https://docNathanM.github.io/chemeng316_fluids/00.03-Solving-Linear-Equations-with-Sympy.html#0.3.3-Solving-linear-equations-using-Sympy)
# * [0.3.3 Solving linear equations using Sympy](https://docNathanM.github.io/chemeng316_fluids/00.03-Solving-Linear-Equations-with-Sympy.html#0.3.3-Solving-linear-equations-using-Sympy)
#
# ### wolframalpha
# * [1.4.1 Situation](https://docNathanM.github.io/chemeng316_fluids/01.04-Queary-Wolfram-Alpha.html#1.4.1-Situation)
# * [1.4.1 Situation](https://docNathanM.github.io/chemeng316_fluids/01.04-Queary-Wolfram-Alpha.html#1.4.1-Situation)
